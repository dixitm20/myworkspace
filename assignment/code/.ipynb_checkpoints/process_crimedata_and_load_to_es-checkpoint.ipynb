# %% [markdown]
# # Copy The Tar Data Files For Each Month(2019-01 To 2019-03) To The Input Data Dir & Untar Those Files.

# %%
from pathlib import Path
import tarfile
import shutil
import os

# Set The Path From Where Process Will Pick The Input Data Files
# It Must Be An Existing Path
srcDataDir = Path('../problem-statement-artifacts/data/').resolve()

# Set The Directory Paths
inputDataDir = Path('../data/indir/').resolve()
procDataDir = Path('../data/procdir/').resolve()
outDataDir = Path('../data/outdir/').resolve()



# If The Directory Already Exist
# Clear The inputdir,procdir And outdir Dir (In Real Life Scenario We May Want To Archive These Dirs ).
if inputDataDir.is_dir():
    shutil.rmtree(str(inputDataDir))
if procDataDir.is_dir():
    shutil.rmtree(str(procDataDir))
if outDataDir.is_dir():
    shutil.rmtree(str(outDataDir))

    
# Create The indir,procdir And outdir Directory If They Do Not Already Exists
Path('../data/indir').mkdir(parents=True, exist_ok=True)
Path('../data/procdir').mkdir(parents=True, exist_ok=True)
Path('../data/outdir').mkdir(parents=True, exist_ok=True)


# Print the Info
print('Source Data Artifacts Dir (This Is Our Source System From Where We Will \
 Pull The Raw Input Files): \n\t{}'.format(srcDataDir))

print('\nInput Data Dir (Contains Raw Input Files): \n\t{}'.format(inputDataDir))

print('\nData Proc Dir (Raw Files Are Oraganized Into Folders Which Will Be Used \
 For Processing These Files): \n\t{}'.format(procDataDir))

print('\nData Out Dir (Contains Final Formated Output Data Files Which Will be \
 Loaded Into Elastic Search): \n\t{}'.format(procDataDir))


# Copy The Tar Files To Input Dir
for file in [file for file in srcDataDir.glob('**/*.gz') if file.is_file()]:
    shutil.copy(str(file), str(inputDataDir))
    
# Untar the Files In Input Dir And Delete The Tar Files
for tfile in [file for file in inputDataDir.glob('**/*.gz') if file.is_file()]:
    tarfile.open(str(tfile)).extractall(str(inputDataDir))
    os.remove(str(tfile))
# Out:
# Source Data Artifacts Dir (This Is Our Source System From Where We Will  Pull The Raw Input Files):
# 	/home/dixitm/myGit/myworkspace/assignment/problem-statement-artifacts/data
#
# Input Data Dir (Contains Raw Input Files):
# 	/home/dixitm/myGit/myworkspace/assignment/data/indir
#
# Data Proc Dir (Raw Files Are Oraganized Into Folders Which Will Be Used  For Processing These Files):
# 	/home/dixitm/myGit/myworkspace/assignment/data/procdir
#
# Data Out Dir (Contains Final Formated Output Data Files Which Will be  Loaded Into Elastic Search):
# 	/home/dixitm/myGit/myworkspace/assignment/data/procdir

# %% [markdown]
# # Check The Files In The indir

# %%
for path,dirs,files in os.walk(str(inputDataDir)):
    print('\n{}'.format(path))
    for f in files:
        print('\t{}'.format(f))
# Out:
# /home/dixitm/myGit/myworkspace/assignment/data/indir
#
# /home/dixitm/myGit/myworkspace/assignment/data/indir/2019-03
# 	2019-03-essex-street.csv
# 	2019-03-north-wales-outcomes.csv
# 	2019-03-cumbria-street.csv
# 	2019-03-norfolk-street.csv
# 	2019-03-warwickshire-outcomes.csv
# 	2019-03-west-mercia-outcomes.csv
# 	2019-03-northern-ireland-street.csv
# 	2019-03-lincolnshire-outcomes.csv
# 	2019-03-south-yorkshire-street.csv
# 	2019-03-cambridgeshire-street.csv
# 	2019-03-metropolitan-outcomes.csv
# 	2019-03-durham-street.csv
# 	2019-03-durham-outcomes.csv
# 	2019-03-cleveland-street.csv
# 	2019-03-west-yorkshire-street.csv
# 	2019-03-dyfed-powys-street.csv
# 	2019-03-hampshire-outcomes.csv
# 	2019-03-thames-valley-street.csv
# 	2019-03-merseyside-street.csv
# 	2019-03-dyfed-powys-outcomes.csv
# 	2019-03-wiltshire-street.csv
# 	2019-03-sussex-outcomes.csv
# 	2019-03-lancashire-street.csv
# 	2019-03-merseyside-outcomes.csv
# 	2019-03-norfolk-outcomes.csv
# 	2019-03-hampshire-street.csv
# 	2019-03-west-mercia-street.csv
# 	2019-03-north-yorkshire-outcomes.csv
# 	2019-03-greater-manchester-street.csv
# 	2019-03-gloucestershire-outcomes.csv
# 	2019-03-west-midlands-outcomes.csv
# 	2019-03-north-wales-street.csv
# 	2019-03-hertfordshire-outcomes.csv
# 	2019-03-surrey-outcomes.csv
# 	2019-03-south-wales-street.csv
# 	2019-03-humberside-street.csv
# 	2019-03-northumbria-outcomes.csv
# 	2019-03-greater-manchester-outcomes.csv
# 	2019-03-gwent-street.csv
# 	2019-03-south-wales-outcomes.csv
# 	2019-03-suffolk-street.csv
# 	2019-03-west-midlands-street.csv
# 	2019-03-humberside-outcomes.csv
# 	2019-03-surrey-street.csv
# 	2019-03-hertfordshire-street.csv
# 	2019-03-kent-outcomes.csv
# 	2019-03-staffordshire-outcomes.csv
# 	2019-03-wiltshire-outcomes.csv
# 	2019-03-dorset-outcomes.csv
# 	2019-03-lincolnshire-street.csv
# 	2019-03-bedfordshire-street.csv
# 	2019-03-warwickshire-street.csv
# 	2019-03-nottinghamshire-outcomes.csv
# 	2019-03-gwent-outcomes.csv
# 	2019-03-north-yorkshire-street.csv
# 	2019-03-devon-and-cornwall-street.csv
# 	2019-03-staffordshire-street.csv
# 	2019-03-bedfordshire-outcomes.csv
# 	2019-03-city-of-london-outcomes.csv
# 	2019-03-lancashire-outcomes.csv
# 	2019-03-sussex-street.csv
# 	2019-03-kent-street.csv
# 	2019-03-cambridgeshire-outcomes.csv
# 	2019-03-metropolitan-street.csv
# 	2019-03-avon-and-somerset-street.csv
# 	2019-03-cumbria-outcomes.csv
# 	2019-03-avon-and-somerset-outcomes.csv
# 	2019-03-northamptonshire-outcomes.csv
# 	2019-03-gloucestershire-street.csv
# 	2019-03-thames-valley-outcomes.csv
# 	2019-03-cleveland-outcomes.csv
# 	2019-03-derbyshire-outcomes.csv
# 	2019-03-suffolk-outcomes.csv
# 	2019-03-leicestershire-outcomes.csv
# 	2019-03-derbyshire-street.csv
# 	2019-03-cheshire-outcomes.csv
# 	2019-03-west-yorkshire-outcomes.csv
# 	2019-03-northamptonshire-street.csv
# 	2019-03-south-yorkshire-outcomes.csv
# 	2019-03-devon-and-cornwall-outcomes.csv
# 	2019-03-dorset-street.csv
# 	2019-03-btp-street.csv
# 	2019-03-northumbria-street.csv
# 	2019-03-city-of-london-street.csv
# 	2019-03-leicestershire-street.csv
# 	2019-03-essex-outcomes.csv
# 	2019-03-nottinghamshire-street.csv
#
# /home/dixitm/myGit/myworkspace/assignment/data/indir/2019-01
# 	2019-01-dorset-outcomes.csv
# 	2019-01-south-wales-outcomes.csv
# 	2019-01-south-yorkshire-street.csv
# 	2019-01-avon-and-somerset-outcomes.csv
# 	2019-01-bedfordshire-outcomes.csv
# 	2019-01-northumbria-street.csv
# 	2019-01-norfolk-street.csv
# 	2019-01-durham-outcomes.csv
# 	2019-01-west-mercia-outcomes.csv
# 	2019-01-west-yorkshire-outcomes.csv
# 	2019-01-merseyside-street.csv
# 	2019-01-essex-outcomes.csv
# 	2019-01-dyfed-powys-outcomes.csv
# 	2019-01-south-yorkshire-outcomes.csv
# 	2019-01-northern-ireland-street.csv
# 	2019-01-greater-manchester-street.csv
# 	2019-01-west-midlands-street.csv
# 	2019-01-kent-outcomes.csv
# 	2019-01-norfolk-outcomes.csv
# 	2019-01-lancashire-street.csv
# 	2019-01-west-mercia-street.csv
# 	2019-01-hertfordshire-outcomes.csv
# 	2019-01-humberside-outcomes.csv
# 	2019-01-leicestershire-street.csv
# 	2019-01-bedfordshire-street.csv
# 	2019-01-warwickshire-street.csv
# 	2019-01-gloucestershire-street.csv
# 	2019-01-warwickshire-outcomes.csv
# 	2019-01-cheshire-street.csv
# 	2019-01-avon-and-somerset-street.csv
# 	2019-01-hampshire-outcomes.csv
# 	2019-01-cleveland-street.csv
# 	2019-01-gloucestershire-outcomes.csv
# 	2019-01-kent-street.csv
# 	2019-01-hertfordshire-street.csv
# 	2019-01-nottinghamshire-outcomes.csv
# 	2019-01-leicestershire-outcomes.csv
# 	2019-01-metropolitan-street.csv
# 	2019-01-merseyside-outcomes.csv
# 	2019-01-lancashire-outcomes.csv
# 	2019-01-northamptonshire-outcomes.csv
# 	2019-01-gwent-outcomes.csv
# 	2019-01-north-yorkshire-street.csv
# 	2019-01-suffolk-outcomes.csv
# 	2019-01-lincolnshire-outcomes.csv
# 	2019-01-durham-street.csv
# 	2019-01-cleveland-outcomes.csv
# 	2019-01-west-midlands-outcomes.csv
# 	2019-01-staffordshire-street.csv
# 	2019-01-cumbria-street.csv
# 	2019-01-cumbria-outcomes.csv
# 	2019-01-surrey-outcomes.csv
# 	2019-01-greater-manchester-outcomes.csv
# 	2019-01-gwent-street.csv
# 	2019-01-wiltshire-street.csv
# 	2019-01-essex-street.csv
# 	2019-01-city-of-london-street.csv
# 	2019-01-sussex-street.csv
# 	2019-01-derbyshire-outcomes.csv
# 	2019-01-cheshire-outcomes.csv
# 	2019-01-staffordshire-outcomes.csv
# 	2019-01-north-yorkshire-outcomes.csv
# 	2019-01-btp-street.csv
# 	2019-01-devon-and-cornwall-outcomes.csv
# 	2019-01-derbyshire-street.csv
# 	2019-01-northumbria-outcomes.csv
# 	2019-01-dyfed-powys-street.csv
# 	2019-01-south-wales-street.csv
# 	2019-01-north-wales-street.csv
# 	2019-01-dorset-street.csv
# 	2019-01-north-wales-outcomes.csv
# 	2019-01-hampshire-street.csv
# 	2019-01-surrey-street.csv
# 	2019-01-nottinghamshire-street.csv
# 	2019-01-northamptonshire-street.csv
# 	2019-01-thames-valley-street.csv
# 	2019-01-wiltshire-outcomes.csv
# 	2019-01-city-of-london-outcomes.csv
# 	2019-01-humberside-street.csv
# 	2019-01-west-yorkshire-street.csv
# 	2019-01-thames-valley-outcomes.csv
# 	2019-01-metropolitan-outcomes.csv
# 	2019-01-cambridgeshire-street.csv
# 	2019-01-lincolnshire-street.csv
# 	2019-01-devon-and-cornwall-street.csv
# 	2019-01-cambridgeshire-outcomes.csv
# 	2019-01-suffolk-street.csv
# 	2019-01-sussex-outcomes.csv
#
# /home/dixitm/myGit/myworkspace/assignment/data/indir/2019-02
# 	2019-02-thames-valley-outcomes.csv
# 	2019-02-dorset-outcomes.csv
# 	2019-02-city-of-london-street.csv
# 	2019-02-north-wales-outcomes.csv
# 	2019-02-northumbria-outcomes.csv
# 	2019-02-northumbria-street.csv
# 	2019-02-warwickshire-outcomes.csv
# 	2019-02-avon-and-somerset-street.csv
# 	2019-02-north-yorkshire-street.csv
# 	2019-02-sussex-street.csv
# 	2019-02-south-wales-street.csv
# 	2019-02-bedfordshire-outcomes.csv
# 	2019-02-hampshire-outcomes.csv
# 	2019-02-cambridgeshire-outcomes.csv
# 	2019-02-northamptonshire-outcomes.csv
# 	2019-02-lincolnshire-outcomes.csv
# 	2019-02-staffordshire-street.csv
# 	2019-02-west-yorkshire-street.csv
# 	2019-02-west-midlands-outcomes.csv
# 	2019-02-west-yorkshire-outcomes.csv
# 	2019-02-warwickshire-street.csv
# 	2019-02-humberside-outcomes.csv
# 	2019-02-merseyside-outcomes.csv
# 	2019-02-south-yorkshire-outcomes.csv
# 	2019-02-suffolk-outcomes.csv
# 	2019-02-north-yorkshire-outcomes.csv
# 	2019-02-avon-and-somerset-outcomes.csv
# 	2019-02-cleveland-outcomes.csv
# 	2019-02-south-wales-outcomes.csv
# 	2019-02-lancashire-outcomes.csv
# 	2019-02-gloucestershire-outcomes.csv
# 	2019-02-durham-outcomes.csv
# 	2019-02-btp-street.csv
# 	2019-02-humberside-street.csv
# 	2019-02-city-of-london-outcomes.csv
# 	2019-02-surrey-outcomes.csv
# 	2019-02-lincolnshire-street.csv
# 	2019-02-devon-and-cornwall-outcomes.csv
# 	2019-02-greater-manchester-street.csv
# 	2019-02-kent-outcomes.csv
# 	2019-02-durham-street.csv
# 	2019-02-kent-street.csv
# 	2019-02-west-mercia-street.csv
# 	2019-02-metropolitan-outcomes.csv
# 	2019-02-gwent-outcomes.csv
# 	2019-02-thames-valley-street.csv
# 	2019-02-wiltshire-outcomes.csv
# 	2019-02-merseyside-street.csv
# 	2019-02-leicestershire-outcomes.csv
# 	2019-02-sussex-outcomes.csv
# 	2019-02-gloucestershire-street.csv
# 	2019-02-norfolk-outcomes.csv
# 	2019-02-dyfed-powys-outcomes.csv
# 	2019-02-west-midlands-street.csv
# 	2019-02-essex-outcomes.csv
# 	2019-02-wiltshire-street.csv
# 	2019-02-cheshire-street.csv
# 	2019-02-bedfordshire-street.csv
# 	2019-02-metropolitan-street.csv
# 	2019-02-norfolk-street.csv
# 	2019-02-greater-manchester-outcomes.csv
# 	2019-02-cambridgeshire-street.csv
# 	2019-02-hampshire-street.csv
# 	2019-02-dorset-street.csv
# 	2019-02-nottinghamshire-street.csv
# 	2019-02-west-mercia-outcomes.csv
# 	2019-02-hertfordshire-outcomes.csv
# 	2019-02-nottinghamshire-outcomes.csv
# 	2019-02-northern-ireland-street.csv
# 	2019-02-suffolk-street.csv
# 	2019-02-cheshire-outcomes.csv
# 	2019-02-devon-and-cornwall-street.csv
# 	2019-02-essex-street.csv
# 	2019-02-lancashire-street.csv
# 	2019-02-cleveland-street.csv
# 	2019-02-derbyshire-street.csv
# 	2019-02-leicestershire-street.csv
# 	2019-02-dyfed-powys-street.csv
# 	2019-02-north-wales-street.csv
# 	2019-02-cumbria-outcomes.csv
# 	2019-02-south-yorkshire-street.csv
# 	2019-02-northamptonshire-street.csv
# 	2019-02-cumbria-street.csv
# 	2019-02-surrey-street.csv
# 	2019-02-derbyshire-outcomes.csv
# 	2019-02-staffordshire-outcomes.csv
# 	2019-02-hertfordshire-street.csv
# 	2019-02-gwent-street.csv

# %% [markdown]
# # Copy The Files Into The procdir And Group Files Of Different Months Into 2 Folders. One Folder street (contains all street files from all months) & Other Folder outcome(all outcome files from all months are placed here)
#
#
# # As We Copy The Files We Also Keep A Running Total Of Count Of Number Of Records In Each Category (street & outcome) Of Files. We Will Use This Count Later To Reconcile The Record Count Once The Data Is Loaded Into The Pandas Dataframe
#
#
# # We also add a column name Rownum containing the line number to each file. We will be using this Rownum to remove Duplicate Records on "Crime ID" which are present within a file.

# %%
# Create The Folders street & outcome In The Procdir
Path(str(procDataDir) + '/street/').mkdir(parents=True, exist_ok=True)
Path(str(procDataDir) + '/outcome/').mkdir(parents=True, exist_ok=True)

# Set The Path Info
procDirStreet=Path(str(procDataDir) + '/street/').resolve()
procDirOutcome=Path(str(procDataDir) + '/outcome/').resolve()

#Print The procdir Subdirtory Details
print('Path For All street Files : \n\t{}'.format(procDirStreet))
print('\nPath For All outcome Files : \n\t{}'.format(procDirOutcome))

# Capture Total Record In street & outcomes Files For Reconciliation
totalStreetRecCount=0
totalOutcomesRecCount=0

# Copy All The street Data Files From inputDataDir To procDirStreet After adding Rownum to each line
for file in [file for file in inputDataDir.glob('**/*-street.csv') if file.is_file()]:
    rownum=0
    with open(str(file), 'r') as recs:
        data = recs.readlines()
    
    with open(str(procDirStreet) + '/' +os.path.basename(file), 'w') as recs:
        for (rownum, line) in enumerate(data):
            if rownum == 0:
                recs.write('{},{}'.format('Rownum', line))
            else:
                recs.write('{},{}'.format(rownum, line))

    # Get number of lines in the present file
    curr_file_num_lines = rownum
    totalStreetRecCount += curr_file_num_lines

    
# Copy All The outcomes Data Files From inputDataDir To procDirOutcome
for file in [file for file in inputDataDir.glob('**/*-outcomes.csv') if file.is_file()]:
    rownum=0
    with open(str(file), 'r') as recs:
        data = recs.readlines()
    
    with open(str(procDirOutcome) + '/' +os.path.basename(file), 'w') as recs:
        for (rownum, line) in enumerate(data):
            if rownum == 0:
                recs.write('{},{}'.format('Rownum', line))
            else:
                recs.write('{},{}'.format(rownum, line))

    # Get number of lines in the present file
    curr_file_num_lines = rownum
    totalOutcomesRecCount += curr_file_num_lines
    
    
print('\n\nTotal street Record Count From All Files: {}'.format(totalStreetRecCount))
print('\nTotal outcomes Record Count From All Files: {}'.format(totalOutcomesRecCount))
# Out:
# Path For All street Files :
# 	/home/dixitm/myGit/myworkspace/assignment/data/procdir/street
#
# Path For All outcome Files :
# 	/home/dixitm/myGit/myworkspace/assignment/data/procdir/outcome
#
#
# Total street Record Count From All Files: 1578168
#
# Total outcomes Record Count From All Files: 1192446

# %% [markdown]
# # Check The Files In The procdir

# %%
for path,dirs,files in os.walk(str(procDataDir)):
    print('\n{}'.format(path))
    for f in files:
        print('\t{}'.format(f))
# Out:
# /home/dixitm/myGit/myworkspace/assignment/data/procdir
#
# /home/dixitm/myGit/myworkspace/assignment/data/procdir/street
# 	2019-03-essex-street.csv
# 	2019-02-city-of-london-street.csv
# 	2019-03-cumbria-street.csv
# 	2019-03-norfolk-street.csv
# 	2019-01-south-yorkshire-street.csv
# 	2019-02-northumbria-street.csv
# 	2019-02-avon-and-somerset-street.csv
# 	2019-01-northumbria-street.csv
# 	2019-02-north-yorkshire-street.csv
# 	2019-03-northern-ireland-street.csv
# 	2019-03-south-yorkshire-street.csv
# 	2019-03-cambridgeshire-street.csv
# 	2019-01-norfolk-street.csv
# 	2019-02-sussex-street.csv
# 	2019-02-south-wales-street.csv
# 	2019-03-durham-street.csv
# 	2019-03-cleveland-street.csv
# 	2019-01-merseyside-street.csv
# 	2019-03-west-yorkshire-street.csv
# 	2019-03-dyfed-powys-street.csv
# 	2019-03-thames-valley-street.csv
# 	2019-01-northern-ireland-street.csv
# 	2019-01-greater-manchester-street.csv
# 	2019-01-west-midlands-street.csv
# 	2019-02-staffordshire-street.csv
# 	2019-01-lancashire-street.csv
# 	2019-01-west-mercia-street.csv
# 	2019-03-merseyside-street.csv
# 	2019-02-west-yorkshire-street.csv
# 	2019-01-leicestershire-street.csv
# 	2019-03-wiltshire-street.csv
# 	2019-02-warwickshire-street.csv
# 	2019-01-bedfordshire-street.csv
# 	2019-03-lancashire-street.csv
# 	2019-01-warwickshire-street.csv
# 	2019-03-hampshire-street.csv
# 	2019-01-gloucestershire-street.csv
# 	2019-03-west-mercia-street.csv
# 	2019-01-cheshire-street.csv
# 	2019-03-greater-manchester-street.csv
# 	2019-01-avon-and-somerset-street.csv
# 	2019-01-cleveland-street.csv
# 	2019-01-kent-street.csv
# 	2019-02-btp-street.csv
# 	2019-03-north-wales-street.csv
# 	2019-02-humberside-street.csv
# 	2019-01-hertfordshire-street.csv
# 	2019-02-lincolnshire-street.csv
# 	2019-02-greater-manchester-street.csv
# 	2019-03-south-wales-street.csv
# 	2019-02-durham-street.csv
# 	2019-01-metropolitan-street.csv
# 	2019-03-humberside-street.csv
# 	2019-02-kent-street.csv
# 	2019-02-west-mercia-street.csv
# 	2019-03-gwent-street.csv
# 	2019-03-suffolk-street.csv
# 	2019-03-west-midlands-street.csv
# 	2019-02-thames-valley-street.csv
# 	2019-03-surrey-street.csv
# 	2019-03-hertfordshire-street.csv
# 	2019-01-north-yorkshire-street.csv
# 	2019-01-durham-street.csv
# 	2019-02-merseyside-street.csv
# 	2019-03-lincolnshire-street.csv
# 	2019-03-bedfordshire-street.csv
# 	2019-03-warwickshire-street.csv
# 	2019-02-gloucestershire-street.csv
# 	2019-01-staffordshire-street.csv
# 	2019-01-cumbria-street.csv
# 	2019-03-north-yorkshire-street.csv
# 	2019-02-west-midlands-street.csv
# 	2019-03-devon-and-cornwall-street.csv
# 	2019-02-wiltshire-street.csv
# 	2019-02-cheshire-street.csv
# 	2019-03-staffordshire-street.csv
# 	2019-02-bedfordshire-street.csv
# 	2019-02-metropolitan-street.csv
# 	2019-02-norfolk-street.csv
# 	2019-02-cambridgeshire-street.csv
# 	2019-01-gwent-street.csv
# 	2019-03-sussex-street.csv
# 	2019-03-kent-street.csv
# 	2019-01-wiltshire-street.csv
# 	2019-03-metropolitan-street.csv
# 	2019-03-avon-and-somerset-street.csv
# 	2019-01-essex-street.csv
# 	2019-01-city-of-london-street.csv
# 	2019-01-sussex-street.csv
# 	2019-02-hampshire-street.csv
# 	2019-01-btp-street.csv
# 	2019-02-dorset-street.csv
# 	2019-02-nottinghamshire-street.csv
# 	2019-01-derbyshire-street.csv
# 	2019-03-gloucestershire-street.csv
# 	2019-01-dyfed-powys-street.csv
# 	2019-01-south-wales-street.csv
# 	2019-02-northern-ireland-street.csv
# 	2019-02-suffolk-street.csv
# 	2019-01-north-wales-street.csv
# 	2019-01-dorset-street.csv
# 	2019-02-devon-and-cornwall-street.csv
# 	2019-02-essex-street.csv
# 	2019-02-lancashire-street.csv
# 	2019-02-cleveland-street.csv
# 	2019-03-derbyshire-street.csv
# 	2019-01-hampshire-street.csv
# 	2019-03-northamptonshire-street.csv
# 	2019-01-surrey-street.csv
# 	2019-02-derbyshire-street.csv
# 	2019-02-leicestershire-street.csv
# 	2019-02-dyfed-powys-street.csv
# 	2019-01-nottinghamshire-street.csv
# 	2019-02-north-wales-street.csv
# 	2019-01-northamptonshire-street.csv
# 	2019-01-thames-valley-street.csv
# 	2019-02-south-yorkshire-street.csv
# 	2019-02-northamptonshire-street.csv
# 	2019-02-cumbria-street.csv
# 	2019-02-surrey-street.csv
# 	2019-03-dorset-street.csv
# 	2019-03-btp-street.csv
# 	2019-03-northumbria-street.csv
# 	2019-03-city-of-london-street.csv
# 	2019-03-leicestershire-street.csv
# 	2019-01-humberside-street.csv
# 	2019-01-west-yorkshire-street.csv
# 	2019-02-hertfordshire-street.csv
# 	2019-01-cambridgeshire-street.csv
# 	2019-01-lincolnshire-street.csv
# 	2019-03-nottinghamshire-street.csv
# 	2019-01-devon-and-cornwall-street.csv
# 	2019-01-suffolk-street.csv
# 	2019-02-gwent-street.csv
#
# /home/dixitm/myGit/myworkspace/assignment/data/procdir/outcome
# 	2019-02-thames-valley-outcomes.csv
# 	2019-03-north-wales-outcomes.csv
# 	2019-02-dorset-outcomes.csv
# 	2019-01-dorset-outcomes.csv
# 	2019-02-north-wales-outcomes.csv
# 	2019-02-northumbria-outcomes.csv
# 	2019-01-south-wales-outcomes.csv
# 	2019-03-warwickshire-outcomes.csv
# 	2019-01-avon-and-somerset-outcomes.csv
# 	2019-02-warwickshire-outcomes.csv
# 	2019-01-bedfordshire-outcomes.csv
# 	2019-03-west-mercia-outcomes.csv
# 	2019-03-lincolnshire-outcomes.csv
# 	2019-01-durham-outcomes.csv
# 	2019-03-metropolitan-outcomes.csv
# 	2019-01-west-mercia-outcomes.csv
# 	2019-01-west-yorkshire-outcomes.csv
# 	2019-03-durham-outcomes.csv
# 	2019-02-bedfordshire-outcomes.csv
# 	2019-01-essex-outcomes.csv
# 	2019-02-hampshire-outcomes.csv
# 	2019-01-dyfed-powys-outcomes.csv
# 	2019-02-cambridgeshire-outcomes.csv
# 	2019-02-northamptonshire-outcomes.csv
# 	2019-03-hampshire-outcomes.csv
# 	2019-02-lincolnshire-outcomes.csv
# 	2019-01-south-yorkshire-outcomes.csv
# 	2019-01-kent-outcomes.csv
# 	2019-01-norfolk-outcomes.csv
# 	2019-01-hertfordshire-outcomes.csv
# 	2019-02-west-midlands-outcomes.csv
# 	2019-01-humberside-outcomes.csv
# 	2019-03-dyfed-powys-outcomes.csv
# 	2019-02-west-yorkshire-outcomes.csv
# 	2019-02-humberside-outcomes.csv
# 	2019-03-sussex-outcomes.csv
# 	2019-02-merseyside-outcomes.csv
# 	2019-02-south-yorkshire-outcomes.csv
# 	2019-02-suffolk-outcomes.csv
# 	2019-03-merseyside-outcomes.csv
# 	2019-03-norfolk-outcomes.csv
# 	2019-02-north-yorkshire-outcomes.csv
# 	2019-01-warwickshire-outcomes.csv
# 	2019-02-avon-and-somerset-outcomes.csv
# 	2019-03-north-yorkshire-outcomes.csv
# 	2019-02-cleveland-outcomes.csv
# 	2019-03-gloucestershire-outcomes.csv
# 	2019-02-south-wales-outcomes.csv
# 	2019-01-hampshire-outcomes.csv
# 	2019-01-gloucestershire-outcomes.csv
# 	2019-02-lancashire-outcomes.csv
# 	2019-02-gloucestershire-outcomes.csv
# 	2019-02-durham-outcomes.csv
# 	2019-03-west-midlands-outcomes.csv
# 	2019-03-hertfordshire-outcomes.csv
# 	2019-02-city-of-london-outcomes.csv
# 	2019-02-surrey-outcomes.csv
# 	2019-01-nottinghamshire-outcomes.csv
# 	2019-02-devon-and-cornwall-outcomes.csv
# 	2019-03-surrey-outcomes.csv
# 	2019-02-kent-outcomes.csv
# 	2019-01-leicestershire-outcomes.csv
# 	2019-01-merseyside-outcomes.csv
# 	2019-03-northumbria-outcomes.csv
# 	2019-01-lancashire-outcomes.csv
# 	2019-02-metropolitan-outcomes.csv
# 	2019-03-greater-manchester-outcomes.csv
# 	2019-03-south-wales-outcomes.csv
# 	2019-02-gwent-outcomes.csv
# 	2019-03-humberside-outcomes.csv
# 	2019-01-northamptonshire-outcomes.csv
# 	2019-01-gwent-outcomes.csv
# 	2019-02-wiltshire-outcomes.csv
# 	2019-03-kent-outcomes.csv
# 	2019-03-staffordshire-outcomes.csv
# 	2019-01-suffolk-outcomes.csv
# 	2019-03-wiltshire-outcomes.csv
# 	2019-01-lincolnshire-outcomes.csv
# 	2019-03-dorset-outcomes.csv
# 	2019-01-cleveland-outcomes.csv
# 	2019-03-nottinghamshire-outcomes.csv
# 	2019-02-leicestershire-outcomes.csv
# 	2019-01-west-midlands-outcomes.csv
# 	2019-02-sussex-outcomes.csv
# 	2019-02-norfolk-outcomes.csv
# 	2019-03-gwent-outcomes.csv
# 	2019-02-dyfed-powys-outcomes.csv
# 	2019-02-essex-outcomes.csv
# 	2019-01-cumbria-outcomes.csv
# 	2019-03-bedfordshire-outcomes.csv
# 	2019-02-greater-manchester-outcomes.csv
# 	2019-01-surrey-outcomes.csv
# 	2019-01-greater-manchester-outcomes.csv
# 	2019-03-city-of-london-outcomes.csv
# 	2019-03-lancashire-outcomes.csv
# 	2019-03-cambridgeshire-outcomes.csv
# 	2019-01-derbyshire-outcomes.csv
# 	2019-03-cumbria-outcomes.csv
# 	2019-03-avon-and-somerset-outcomes.csv
# 	2019-01-cheshire-outcomes.csv
# 	2019-01-staffordshire-outcomes.csv
# 	2019-01-north-yorkshire-outcomes.csv
# 	2019-03-northamptonshire-outcomes.csv
# 	2019-01-devon-and-cornwall-outcomes.csv
# 	2019-02-west-mercia-outcomes.csv
# 	2019-01-northumbria-outcomes.csv
# 	2019-03-thames-valley-outcomes.csv
# 	2019-02-hertfordshire-outcomes.csv
# 	2019-02-nottinghamshire-outcomes.csv
# 	2019-03-cleveland-outcomes.csv
# 	2019-03-derbyshire-outcomes.csv
# 	2019-02-cheshire-outcomes.csv
# 	2019-03-suffolk-outcomes.csv
# 	2019-03-leicestershire-outcomes.csv
# 	2019-03-cheshire-outcomes.csv
# 	2019-01-north-wales-outcomes.csv
# 	2019-03-west-yorkshire-outcomes.csv
# 	2019-02-cumbria-outcomes.csv
# 	2019-03-south-yorkshire-outcomes.csv
# 	2019-03-devon-and-cornwall-outcomes.csv
# 	2019-02-derbyshire-outcomes.csv
# 	2019-01-wiltshire-outcomes.csv
# 	2019-02-staffordshire-outcomes.csv
# 	2019-03-essex-outcomes.csv
# 	2019-01-city-of-london-outcomes.csv
# 	2019-01-thames-valley-outcomes.csv
# 	2019-01-metropolitan-outcomes.csv
# 	2019-01-cambridgeshire-outcomes.csv
# 	2019-01-sussex-outcomes.csv

# %% [markdown]
# # Load The File Data Into Pandas Dataframes

# %%
import pandas as pd
import numpy as np

# List All the street And outcomes
streetfileList=[str(file) for file in procDirStreet.glob('**/*-street.csv') if file.is_file()]
outcomefileList=[str(file) for file in procDirOutcome.glob('**/*-outcomes.csv') if file.is_file()]
 
# Map function which will read the csv file and also add one more column named "District name" to 
# the output dataframe
def read_csv_with_districtname_from_file(inputfile):
    outdf=pd.read_csv(inputfile)
    filename=os.path.basename(inputfile)
    districtname=filename[8:].replace('-street.csv','').replace('-outcomes.csv','')
    outdf['District name']=districtname
    return outdf
   
    
# Load The Data Into The Pandas Dataframes
dfStreet = pd.concat(map(read_csv_with_districtname_from_file, streetfileList))
dfOutcomes = pd.concat(map(read_csv_with_districtname_from_file, outcomefileList))

# %% [markdown]
# # Keep Columns Which Are Required

# %%
print('street data column list before dropping extra cols: \n{}'.format(dfStreet.columns))
print('\noutcome data column list before dropping extra cols: \n{}'.format(dfOutcomes.columns))

dfStreet=dfStreet[['Rownum', 'Crime ID', 'Month', 'Longitude', 'Latitude', 'Crime type', 'Last outcome category', 'District name']]
dfOutcomes=dfOutcomes[['Rownum', 'Crime ID', 'Month', 'Longitude', 'Latitude', 'Outcome type', 'District name']]

print('\n\nstreet data column list after dropping extra cols: \n{}'.format(dfStreet.columns))
print('\noutcome data column list after dropping extra cols: \n{}'.format(dfOutcomes.columns))
# Out:
# street data column list before dropping extra cols:
# Index(['Rownum', 'Crime ID', 'Month', 'Reported by', 'Falls within',
#        'Longitude', 'Latitude', 'Location', 'LSOA code', 'LSOA name',
#        'Crime type', 'Last outcome category', 'Context', 'District name'],
#       dtype='object')
#
# outcome data column list before dropping extra cols:
# Index(['Rownum', 'Crime ID', 'Month', 'Reported by', 'Falls within',
#        'Longitude', 'Latitude', 'Location', 'LSOA code', 'LSOA name',
#        'Outcome type', 'District name'],
#       dtype='object')
#
#
# street data column list after dropping extra cols:
# Index(['Rownum', 'Crime ID', 'Month', 'Longitude', 'Latitude', 'Crime type',
#        'Last outcome category', 'District name'],
#       dtype='object')
#
# outcome data column list after dropping extra cols:
# Index(['Rownum', 'Crime ID', 'Month', 'Longitude', 'Latitude', 'Outcome type',
#        'District name'],
#       dtype='object')

# %% [markdown]
# # Reconcile the Record Counts In street & outcomes Files With The Counts Loaded In The dataframes

# %%
if dfStreet.shape[0] == totalStreetRecCount:
    print('SUCCESS: Record Count Match Between dfStreet dataframe: {} \
& Total Street Records: {}'.format(dfStreet.shape[0],totalStreetRecCount))
else:
    print('\nFATAL: Record Count Mismatch Between dfStreet dataframe: {} \
& Total Street Records: {}'.format(dfStreet.shape[0],totalStreetRecCount))
    
if dfOutcomes.shape[0] == totalOutcomesRecCount:
    print('\nSUCCESS: Record Count Match Between dfStreet dataframe: {} \
& Total Street Records: {}'.format(dfOutcomes.shape[0],totalOutcomesRecCount))
else:
    print('\nFATAL: Record Count Mismatch Between dfStreet dataframe: {} \
& Total Street Records: {}'.format(dfOutcomes.shape[0],totalOutcomesRecCount))
# Out:
# SUCCESS: Record Count Match Between dfStreet dataframe: 1578168 & Total Street Records: 1578168
#
# SUCCESS: Record Count Match Between dfStreet dataframe: 1192446 & Total Street Records: 1192446

# %% [markdown]
# # Apply Schema To The DataFrames
#
# # Convert Month From string value: 2019-01 to integer: 201901

# %%
commonColunsInStreetAndOutcomes=[]

print('Columns In street Dataframe: {}'.format(dfStreet.columns.shape[0]))
print('-----------------------------')
for col in dfStreet.columns:
    if col in ['Latitude','Longitude']:
        dfStreet[col]=dfStreet[col].astype(float)
    elif col in ['Month','Rownum']:
        if 'int' not in str(dfStreet[col].dtype):
            dfStreet[col]=dfStreet[col].str.replace('-','').astype(int)
    else:
        dfStreet[col]=dfStreet[col].astype(str)
    print('Column Name: {}, Data Type: {}'.format(col,dfStreet[col].dtype))

    
print('\nColumns In outcome Dataframe: {}'.format(dfOutcomes.columns.shape[0]))
print('-----------------------------')
for col in dfOutcomes.columns:
    if col in ['Latitude','Longitude']:
        dfOutcomes[col]=dfOutcomes[col].astype(float)
    elif col in ['Month','Rownum']:
        if 'int' not in str(dfOutcomes[col].dtype):
            dfOutcomes[col]=dfOutcomes[col].str.replace('-','').astype(int)
    else:
        dfOutcomes[col]=dfOutcomes[col].astype(str)
    print('Column Name: {}, Data Type: {}'.format(col,dfOutcomes[col].dtype))
    if col in dfStreet.columns:
        commonColunsInStreetAndOutcomes.append(col)
        

print('\nCommon Columns In street & outcome Dataframe: {}'.format(len(commonColunsInStreetAndOutcomes)))
print('-----------------------------')
for col in commonColunsInStreetAndOutcomes:
    print(col)
# Out:
# Columns In street Dataframe: 8
# -----------------------------
# Column Name: Rownum, Data Type: int64
# Column Name: Crime ID, Data Type: object
# Column Name: Month, Data Type: int64
# Column Name: Longitude, Data Type: float64
# Column Name: Latitude, Data Type: float64
# Column Name: Crime type, Data Type: object
# Column Name: Last outcome category, Data Type: object
# Column Name: District name, Data Type: object
#
# Columns In outcome Dataframe: 7
# -----------------------------
# Column Name: Rownum, Data Type: int64
# Column Name: Crime ID, Data Type: object
# Column Name: Month, Data Type: int64
# Column Name: Longitude, Data Type: float64
# Column Name: Latitude, Data Type: float64
# Column Name: Outcome type, Data Type: object
# Column Name: District name, Data Type: object
#
# Common Columns In street & outcome Dataframe: 6
# -----------------------------
# Rownum
# Crime ID
# Month
# Longitude
# Latitude
# District name

# %% [markdown]
# # Peek Into The Data Loaded in Dataframes

# %%
print('Shape Of The street Dataframe: {}'.format(dfStreet.shape))
dfStreet.head()
# Out:
# Shape Of The street Dataframe: (1578168, 8)
#    Rownum                                           Crime ID   Month  \
# 0       1  95e304d9e476cb5611111d51a3e258298232ba5bfafccb...  201903
# 1       2  4bfda2e430113728d4683311c7bcafa6f92638e208f0c1...  201903
# 2       3  13c85cc749572b0aad9375f680b939de8db7414e0cc84a...  201903
# 3       4  f4741e818da6bed6b6060584b295c4096bfd0341d95158...  201903
# 4       5  6327dda5672144ac58e84036d1a39477db4e6e0e180ec8...  201903
#
#    Longitude   Latitude                    Crime type  \
# 0  -0.986073  51.935250  Violence and sexual offences
# 1   0.806772  51.967013                      Burglary
# 2   0.887522  51.992391                   Other theft
# 3   0.873053  51.970504  Violence and sexual offences
# 4   0.158232  51.553923                      Burglary
#
#                            Last outcome category District name
# 0                    Unable to prosecute suspect         essex
# 1  Investigation complete; no suspect identified         essex
# 2  Investigation complete; no suspect identified         essex
# 3  Investigation complete; no suspect identified         essex
# 4                            Under investigation         essex

# %%
print('Shape Of The street Dataframe: {}'.format(dfOutcomes.shape))
dfOutcomes.head()
# Out:
# Shape Of The street Dataframe: (1192446, 7)
#    Rownum                                           Crime ID   Month  \
# 0       1  c2fd1e9d414ec69ce0b1c64d12eead0175062836d7833c...  201902
# 1       2  3d53d898b6af04e4ccc6429f9539da122eb25ce0117ba1...  201902
# 2       3  a08159d3c4ecb568e48e4cd752f608cd3db4bf21cdf830...  201902
# 3       4  8ca408c4088ed308a2b964be2dbeca0dc3a8ccb1b4f9da...  201902
# 4       5  435381746e98bc5702b776751daf7a432401f7e22e5d01...  201902
#
#    Longitude  Latitude                              Outcome type  \
# 0        NaN       NaN  Offender given suspended prison sentence
# 1        NaN       NaN                   Offender sent to prison
# 2        NaN       NaN                   Offender sent to prison
# 3        NaN       NaN                   Offender sent to prison
# 4        NaN       NaN             Defendant sent to Crown Court
#
#    District name
# 0  thames-valley
# 1  thames-valley
# 2  thames-valley
# 3  thames-valley
# 4  thames-valley

# %% [markdown]
# # Clean the street & outcomes Dataframe by following the below stops:
#
# # 1) Removing duplicates on 'Crime ID','District name'. We retain the record with the maximum value of Month and In case we have more than one entry for the same 'Crime ID','District name' In the same month then we retain the record which has highest line number in a given file.
#
# # 2) Delete the records from both the datasets where 'Crime ID' is not available
#
# # 3) Keep only those columns which are needed in the final output dataset

# %%
rmd_dfStreet=dfStreet.sort_values(['Crime ID','District name','Month','Rownum'])\
.drop_duplicates(['Crime ID'],'last')

rmd_clean_dfStreet=rmd_dfStreet[rmd_dfStreet['Crime ID'] != 'nan']

rmd_clean_dfStreet=rmd_clean_dfStreet[['Crime ID', 'District name', 'Latitude'\
                                       , 'Longitude', 'Crime type', 'Last outcome category']]

print('Shape Of street dataset Before remove duplicate & nan drop on Crime Id: {}'\
      .format(dfStreet.shape))
print('Shape Of street dataset After remove duplicate & nan drop on Crime Id: {}'\
      .format(rmd_clean_dfStreet.shape))

rmd_clean_dfStreet.head()
# Out:
# Shape Of street dataset Before remove duplicate & nan drop on Crime Id: (1578168, 8)
# Shape Of street dataset After remove duplicate & nan drop on Crime Id: (1229828, 6)
#                                                 Crime ID      District name  \
# 251    00000983358084d4e70b1ca90be352591bf506a6efda82...    north-yorkshire
# 13296  000022121d7fe64bb8a4c44497571b4a4f71ddb4f50368...  avon-and-somerset
# 2891   000035d52fae4f276492b3b1599eecbf3f1f1279e26ffc...              essex
# 809    0000444a0b278a28da9e0dcb866584d3883289f6455ae9...      west-midlands
# 87322  0000447043b24b920901e592522376db5be84b85e3ebbd...       metropolitan
#
#         Latitude  Longitude                    Crime type  \
# 251    53.897553  -1.992842                      Burglary
# 13296        NaN        NaN  Violence and sexual offences
# 2891   51.785544   0.618594                   Other theft
# 809    52.539277  -1.886178                 Vehicle crime
# 87322  51.533896  -0.189401                      Burglary
#
#                                Last outcome category
# 251                              Under investigation
# 13296                    Unable to prosecute suspect
# 2891   Investigation complete; no suspect identified
# 809    Investigation complete; no suspect identified
# 87322                            Under investigation

# %%
rmd_dfOutcomes=dfOutcomes.sort_values(['Crime ID','District name','Month','Rownum'])\
.drop_duplicates(['Crime ID'],'last')

rmd_clean_dfOutcomes=rmd_dfOutcomes[rmd_dfOutcomes['Crime ID'] != 'nan']

rmd_clean_dfOutcomes=rmd_clean_dfOutcomes[['Crime ID','Outcome type']]

rmd_clean_dfOutcomes['Join_Flag']=1

print('Shape Of outcomes dataset Before remove duplicate & nan drop on Crime Id: {}'\
      .format(dfOutcomes.shape))
print('Shape Of outcomes dataset After remove duplicate & nan drop  on Crime Id: {}'\
      .format(rmd_clean_dfOutcomes.shape))

rmd_clean_dfOutcomes.head()
# Out:
# Shape Of outcomes dataset Before remove duplicate & nan drop on Crime Id: (1192446, 7)
# Shape Of outcomes dataset After remove duplicate & nan drop  on Crime Id: (1091966, 3)
#                                                 Crime ID  \
# 4070   000022121d7fe64bb8a4c44497571b4a4f71ddb4f50368...
# 1425   000022c155a80d717523dee51b31e08e28cfaa760b467a...
# 10799  000035d52fae4f276492b3b1599eecbf3f1f1279e26ffc...
# 8826   0000444a0b278a28da9e0dcb866584d3883289f6455ae9...
# 23637  00004b0f856f8989c91e674b9167d8c1a1a8665af7f191...
#
#                                         Outcome type  Join_Flag
# 4070                     Unable to prosecute suspect          1
# 1425                     Unable to prosecute suspect          1
# 10799  Investigation complete; no suspect identified          1
# 8826   Investigation complete; no suspect identified          1
# 23637  Investigation complete; no suspect identified          1

# %% [markdown]
# # Join The street & outcomes clean datasets to produce the outut dataset

# %%
dfStreetXoutcomes = pd.merge(rmd_clean_dfStreet, rmd_clean_dfOutcomes,  \
                  how='left', left_on=['Crime ID'], right_on = ['Crime ID'])

# %% [markdown]
# # Print stats about the matched and unmatched records

# %%
print('Total Count Of Distinct Crime ID present in the street dataset: {}'\
      .format(rmd_clean_dfStreet.shape[0]))

print('Crime ID in street which found match in outcomes: {}'\
      .format(dfStreetXoutcomes[dfStreetXoutcomes['Join_Flag'] ==1].shape[0]))

print('Crime ID in street which did not found match in outcomes: {}'\
      .format(dfStreetXoutcomes[dfStreetXoutcomes['Join_Flag'] !=1].shape[0]))

print('\nShape of the join dataset: {}'.format(dfStreetXoutcomes.shape))
print('\nColumns of the join dataset: {}'.format(dfStreetXoutcomes.columns))
dfStreetXoutcomes.head()
# Out:
# Total Count Of Distinct Crime ID present in the street dataset: 1229828
# Crime ID in street which found match in outcomes: 738284
# Crime ID in street which did not found match in outcomes: 491544
#
# Shape of the join dataset: (1229828, 8)
#
# Columns of the join dataset: Index(['Crime ID', 'District name', 'Latitude', 'Longitude', 'Crime type',
#        'Last outcome category', 'Outcome type', 'Join_Flag'],
#       dtype='object')
#                                             Crime ID      District name  \
# 0  00000983358084d4e70b1ca90be352591bf506a6efda82...    north-yorkshire
# 1  000022121d7fe64bb8a4c44497571b4a4f71ddb4f50368...  avon-and-somerset
# 2  000035d52fae4f276492b3b1599eecbf3f1f1279e26ffc...              essex
# 3  0000444a0b278a28da9e0dcb866584d3883289f6455ae9...      west-midlands
# 4  0000447043b24b920901e592522376db5be84b85e3ebbd...       metropolitan
#
#     Latitude  Longitude                    Crime type  \
# 0  53.897553  -1.992842                      Burglary
# 1        NaN        NaN  Violence and sexual offences
# 2  51.785544   0.618594                   Other theft
# 3  52.539277  -1.886178                 Vehicle crime
# 4  51.533896  -0.189401                      Burglary
#
#                            Last outcome category  \
# 0                            Under investigation
# 1                    Unable to prosecute suspect
# 2  Investigation complete; no suspect identified
# 3  Investigation complete; no suspect identified
# 4                            Under investigation
#
#                                     Outcome type  Join_Flag
# 0                                            NaN        NaN
# 1                    Unable to prosecute suspect        1.0
# 2  Investigation complete; no suspect identified        1.0
# 3  Investigation complete; no suspect identified        1.0
# 4                                            NaN        NaN

# %% [markdown]
# # Derive lastOutcome column based on the join_flag

# %%
dfStreetXoutcomes['lastOutcome']=np.where(dfStreetXoutcomes['Join_Flag']==1, \
                                dfStreetXoutcomes['Outcome type'], dfStreetXoutcomes['Last outcome category'])

# %% [markdown]
# # Peek at the output to verify the lastOutcome column derivation

# %%
dfStreetXoutcomes.head()
# Out:
#                                             Crime ID      District name  \
# 0  00000983358084d4e70b1ca90be352591bf506a6efda82...    north-yorkshire
# 1  000022121d7fe64bb8a4c44497571b4a4f71ddb4f50368...  avon-and-somerset
# 2  000035d52fae4f276492b3b1599eecbf3f1f1279e26ffc...              essex
# 3  0000444a0b278a28da9e0dcb866584d3883289f6455ae9...      west-midlands
# 4  0000447043b24b920901e592522376db5be84b85e3ebbd...       metropolitan
#
#     Latitude  Longitude                    Crime type  \
# 0  53.897553  -1.992842                      Burglary
# 1        NaN        NaN  Violence and sexual offences
# 2  51.785544   0.618594                   Other theft
# 3  52.539277  -1.886178                 Vehicle crime
# 4  51.533896  -0.189401                      Burglary
#
#                            Last outcome category  \
# 0                            Under investigation
# 1                    Unable to prosecute suspect
# 2  Investigation complete; no suspect identified
# 3  Investigation complete; no suspect identified
# 4                            Under investigation
#
#                                     Outcome type  Join_Flag  \
# 0                                            NaN        NaN
# 1                    Unable to prosecute suspect        1.0
# 2  Investigation complete; no suspect identified        1.0
# 3  Investigation complete; no suspect identified        1.0
# 4                                            NaN        NaN
#
#                                      lastOutcome
# 0                            Under investigation
# 1                    Unable to prosecute suspect
# 2  Investigation complete; no suspect identified
# 3  Investigation complete; no suspect identified
# 4                            Under investigation

# %% [markdown]
# # Rename the columns and as per the final output dataset and keep only the required columns

# %%
dfStreetXoutcomes=dfStreetXoutcomes[['Crime ID','District name','Latitude','Longitude','Crime type','lastOutcome']]

dfStreetXoutcomes = dfStreetXoutcomes.astype(object).replace(np.nan, 'none')
dfStreetXoutcomes = dfStreetXoutcomes.astype(object).replace('nan', 'none')

dfFinalOut4ES=dfStreetXoutcomes.rename(index=str, columns={'Crime ID': 'crimeId','District name': 'districtName'\
                ,'Latitude': 'latitude','Longitude': 'longitude','Crime type': 'crimeType'})

# %% [markdown]
# # Print Stats about the Final dataset

# %%
print('Shape Of the Final Dataset (Ready For Load Into Elastic Search: {}'\
      .format(dfFinalOut4ES.shape))

print('\nColumns Of the Final Dataset (Ready For Load Into Elastic Search: \n{}'\
      .format(dfFinalOut4ES.columns))

dfFinalOut4ES.head()
# Out:
# Shape Of the Final Dataset (Ready For Load Into Elastic Search: (1229828, 6)
#
# Columns Of the Final Dataset (Ready For Load Into Elastic Search:
# Index(['crimeId', 'districtName', 'latitude', 'longitude', 'crimeType',
#        'lastOutcome'],
#       dtype='object')
#                                              crimeId       districtName  \
# 0  00000983358084d4e70b1ca90be352591bf506a6efda82...    north-yorkshire
# 1  000022121d7fe64bb8a4c44497571b4a4f71ddb4f50368...  avon-and-somerset
# 2  000035d52fae4f276492b3b1599eecbf3f1f1279e26ffc...              essex
# 3  0000444a0b278a28da9e0dcb866584d3883289f6455ae9...      west-midlands
# 4  0000447043b24b920901e592522376db5be84b85e3ebbd...       metropolitan
#
#   latitude longitude                     crimeType  \
# 0  53.8976  -1.99284                      Burglary
# 1     none      none  Violence and sexual offences
# 2  51.7855  0.618594                   Other theft
# 3  52.5393  -1.88618                 Vehicle crime
# 4  51.5339 -0.189401                      Burglary
#
#                                      lastOutcome
# 0                            Under investigation
# 1                    Unable to prosecute suspect
# 2  Investigation complete; no suspect identified
# 3  Investigation complete; no suspect identified
# 4                            Under investigation

# %% [markdown]
# # Write The final output dataset to file

# %%
dfFinalOut4ES.to_csv(str(outDataDir)+'/out-dataset-for-elasticSearch-upload.csv')

# %% [markdown]
# # Load The Data To Elastic Search

# %%
from elasticsearch import Elasticsearch
from elasticsearch import helpers
es = Elasticsearch(http_compress=True)

# %%
def doc_generator(df):
    df_iter = df.iterrows()
    for index, document in df_iter:
        yield {
                "_index": 'crimedetails',
                "_type": "_doc",
                "_id" : f"{document['crimeId']}",
                "_source": document[['districtName','latitude','longitude','crimeType','lastOutcome']].to_dict(),
            }

# %%
# Convert the float types to string to avoid number format exception 
# while loading the data to elastic search
dfFinalOut4ES['latitude']=dfFinalOut4ES['latitude'].astype(str)
dfFinalOut4ES['longitude']=dfFinalOut4ES['longitude'].astype(str)


helpers.bulk(es, doc_generator(dfFinalOut4ES))
# Out:
# (1229828, [])
